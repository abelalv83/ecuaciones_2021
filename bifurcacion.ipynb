# %%
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import numpy as np

# Ecuacion Diferencial: dy/dx=f(x,y)
        

c=-0.5
def f( y,x): 
    
    return y*(1-y)+c
    



# Campo de pendientes
N = 30  # numero de pendientes a graficar
xi = 0
xf = 5  # dominio
x = np.linspace(xi, xf, N)
y = np.linspace(-1, K+0.5*K, N)
X, Y = np.meshgrid(x, y)
U = 1
V = f(Y,X)
U2, V2 = U/np.sqrt(U**2+V**2), V/np.sqrt(U**2+V**2)
#plt.quiver(X, Y, U2, V2, color='k')
#plt.grid(True)
#plt.title(r'Campo de pendientes: $\frac{dy}{dx}=ry(1-\frac{y}{K})$')
# initial condition
y0 = [0.3, 0.4, 0.5, 4, 3.6]

# time points
t = np.linspace(0, xf)

# solve ODE
for yi in y0:
    y = odeint(f, yi, t, rtol=1.0E-8)
    plt.plot(t, y)

# plot results

plt.xlabel('time')
plt.ylabel('y(t)')
plt.quiver(X, Y, U2, V2, color='k')
plt.grid(True)
plt.title(
    r'Campo de pendientesny solución de la ecuación: $y(1-y)+c$')
# Out:
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# /usr/local/lib/python3.7/dist-packages/scipy/integrate/odepack.py:248: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)
# Text(0.5, 1.0, 'Campo de pendientesny solución de la ecuación: $y(1-y)+c$')
