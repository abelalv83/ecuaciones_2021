# %% [markdown]
# # Taller de respaso

# %% [markdown]
# 1. Verifique la función $y=C_1e^{x}+C_2e^{-x}$ es solución de $$y''-y=0$$
#
# 2. Verifique que la función $y=C_1+C_2\cos x+ C_3\sin x$ es solución de la ecuación
# $$y'''+y'=0$$
#
# 3. Determine los coeficientes $C_1$ y $C_2$ de la función $y=c_1+c_2x\ln(x)$, la cual es solcuión de la ecuación $$x^2y''-xy+y=0$$ con condiciones iniciales
# $y(1)=3$ y $y'(1)=2$
#
# 4. ¿Qué es una solución particular de una ecuación lineal de segundo orden? De ejemplos
#
# 5. ¿Que es una ecuación diferencial lineal homogenea de coeficientes constantes de segundo orden? De ejemplos
#
# 6. Resulva las siguientes ecuaciones difeenciales:
#
#   a. $4y''+y'=0$
#
#   b. $12y''-5y'-2y=0$
#
#   c. $3y''+2y+y=0$
#
#   d. $3y''+y=0$
#
# 7. Escribas las ecuaciones diferenciales anteriores ene forma de sistemas
#
# 8. Resuelva las siguientes ecuaciones diferenciales
#
#   a. $y''+3y'+2y=6$
#
#   b. $\frac{1}{4}y''+y'+y=x^2-2x$
#
#   c. $y''-y'=-3$
#
#   d. $y''-y'+\frac{1}{4}y=3+e^{x/2}$
#
#   e. $y''-16y=2e^{4t}$
#
#   f. $y''+y=2x\sin x$
#
# 9. Resuleva el problema con valores iniciales
#
#       a. $y''+4y=-2$ con $y(\pi/8)=1/2$ y $y'(\pi/8)=2$
#
#       b. $y''+4y'+5y=35e^{-4x}$ y $y(0)=-3$ y $y'(0)=1$
#
# 10. REsuelva los siguientes sistemas de ecuaciones
#
#     a.
#   $\begin{cases}x'=x+2y\\y'=4x+3y \end{cases}$
#
#     b.
#   $\begin{cases}x'=2x+2y\\y'=x+3y\end{cases}$
#
#     c.
#   $\begin{cases}x'=-4x+2y\\y'=-\frac{5}{2}x+2y\end{cases}$
#
# 11. Encuentre de los sistemas anteriores:
#
#   a. los puntos de equilibrio
#
#   b. Realice el diagrama de fase
#
#   c. Interprete que sucede si la condición inicial es $x(0)=1$ y $y(0)=1$ cuando $t\to \infty$
