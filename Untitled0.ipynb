# %%
import sympy as sy
sy.init_printing(use_latex='mathjax') # para mejor despliege de la EDO
# aqui definimos la variables Note que y es un afunción y x es la variable independiente
t = sy.Symbol('t')
y = sy.Function('y')
q=sy.Eq(y(t).diff(t),-2*y(t)/t+t-1)
sy.dsolve(q,y(t))
# Out:
#              2
#        C₁   t    t
# y(t) = ── + ── - ─
#         2   4    3
#        t
