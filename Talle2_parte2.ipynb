# %% [markdown]
# # Taller de solución de segundo orden

# %% [markdown]
# 1.   Determine la solución general de los siguietes problemas
#
#   * $y''+2y'+4y=t+\cos(2t)$
#   * $y''+y'+y=5\sin(t)$
#   * $\theta''=2\theta'-\theta+2e^x$

# %% [markdown]
# 2.   Determine la solución de problema con valores iniciales
#
#   * $y''=6t$ con $y(0)=3$ y $y'(0)=-1$
#   *  $ y''(\theta)-y(\theta)=\sin(\theta)-e^{2\theta}$   con $y(0)=1$ y $y'(0)=-1$
#   * $x''+2x'+x=t^2+1-e^t$  con $x(0)=0$ y $x'(0)=2$
