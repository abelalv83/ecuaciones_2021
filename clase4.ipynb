# %% [markdown]
# # taller 4
# Aquí formularemos alguns problemas de ecuaciones diferenciales ordinarias de primer orden lineales
#
# 1. Sea la ecuación
#
# $$y'=3y-\frac{1}{x}$$
#
# a. La ecuación tiene una unica solución
#
# b. ¿Cuál es la solución?
#
# c. Si tenemos que $y(0.1)=1$ ¿cúal es el intervalo de solución de esta ecuación? ¿Es única?
#
# d. Encuentre la socución para el punto c.

# %%
print('hola mundo ')
